# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.keywords)
print(example.reference_answer)
print(example.category)
# Out:
# Who won the prestigious IIOTY award in 2023?
# ['Maxine', 'Thompson', 'IIOTY']
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# direct_fact

# %%
from collections import Counter
count = Counter(test.category for test in tests)
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
tests = test.load_tests()

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.6666666666666666, ndcg=0.0, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunk = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies the award and year but only provides the first name 'Maxine' instead of the full name 'Maxine Thompson' from the reference. This makes accuracy incorrect and reduces completeness since the surname is missing. It directly answers who won (relevance is high) and includes the award name and year, but the missing full name is a notable omission.", accuracy=1.0, completness=3.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completness)
print(eval.relevance)
# Out:
# The answer correctly identifies the award and year but only provides the first name 'Maxine' instead of the full name 'Maxine Thompson' from the reference. This makes accuracy incorrect and reduces completeness since the surname is missing. It directly answers who won (relevance is high) and includes the award name and year, but the missing full name is a notable omission.
# 1.0
# 3.0
# 5.0
